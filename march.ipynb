# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn import linear_model

# %%
df=pd.read_excel('data.xlsx')
df
# Out:
#                 Hourly time   gs_ws10   gs_ws30   gs_ws60   gs_ws90  gs_ws120  \
# 0   2019-03-01 00:00:00.000  1.643117  1.897483  2.046550  2.789317  2.244717
# 1   2019-03-01 01:00:00.000  1.617617  2.280700  2.741900  3.480817  3.781433
# 2   2019-03-01 01:59:59.990  1.389533  2.063233  3.060400  3.832967  4.584933
# 3   2019-03-01 02:59:59.985  1.690217  2.452900  3.340983  3.868650  4.409583
# 4   2019-03-01 03:59:59.980  1.622933  2.231233  2.945917  3.505633  3.736650
# ..                      ...       ...       ...       ...       ...       ...
# 739 2019-03-31 19:00:00.000  4.265117  5.152417  6.356683  5.661567  7.652633
# 740 2019-03-31 20:00:00.000  3.141467  4.008933  5.043733  4.813683  6.795983
# 741 2019-03-31 21:00:00.000  1.592217  2.607700  3.862900  3.972467  5.501300
# 742 2019-03-31 22:00:00.000  1.127750  1.595333  2.445300  3.272283  3.931333
# 743 2019-03-31 23:00:00.000  2.784800  3.761817  4.480900  4.426517  5.215183
#
#      satellite_ws10  satellite_ws50  temp_2
# 0              1.44            2.35   27.46
# 1              1.28            2.41   26.91
# 2              1.13            2.44   26.42
# 3              1.08            2.39   25.92
# 4              1.14            2.34   25.46
# ..              ...             ...     ...
# 739            4.83            6.46   31.15
# 740            5.08            6.55   29.62
# 741            4.76            6.13   28.63
# 742            4.34            5.55   28.00
# 743            3.98            5.18   27.48
#
# [744 rows x 9 columns]

# %%
df=pd.read_excel('data.xlsx',index_col=0,nrows=480)
df
# Out:
#                           gs_ws10   gs_ws30   gs_ws60   gs_ws90  gs_ws120  \
# Hourly time
# 2019-03-01 00:00:00.000  1.643117  1.897483  2.046550  2.789317  2.244717
# 2019-03-01 01:00:00.000  1.617617  2.280700  2.741900  3.480817  3.781433
# 2019-03-01 01:59:59.990  1.389533  2.063233  3.060400  3.832967  4.584933
# 2019-03-01 02:59:59.985  1.690217  2.452900  3.340983  3.868650  4.409583
# 2019-03-01 03:59:59.980  1.622933  2.231233  2.945917  3.505633  3.736650
# ...                           ...       ...       ...       ...       ...
# 2019-03-20 19:00:00.000  4.585017  5.175383  5.788667  5.396667  7.016683
# 2019-03-20 20:00:00.000  3.883667  4.580533  5.646767  5.392200  6.588100
# 2019-03-20 21:00:00.000  2.242667  2.843150  3.667117  4.059533  4.572683
# 2019-03-20 22:00:00.000  1.242217  1.751483  2.307600  3.086350  2.811067
# 2019-03-20 23:00:00.000  1.120217  1.659300  2.161217  2.980650  2.592933
#
#                          satellite_ws10  satellite_ws50  temp_2
# Hourly time
# 2019-03-01 00:00:00.000            1.44            2.35   27.46
# 2019-03-01 01:00:00.000            1.28            2.41   26.91
# 2019-03-01 01:59:59.990            1.13            2.44   26.42
# 2019-03-01 02:59:59.985            1.08            2.39   25.92
# 2019-03-01 03:59:59.980            1.14            2.34   25.46
# ...                                 ...             ...     ...
# 2019-03-20 19:00:00.000            1.82            3.75   29.30
# 2019-03-20 20:00:00.000            1.47            2.99   28.19
# 2019-03-20 21:00:00.000            1.27            2.39   27.32
# 2019-03-20 22:00:00.000            1.13            1.91   26.62
# 2019-03-20 23:00:00.000            1.01            1.62   26.05
#
# [480 rows x 8 columns]

# %%
df.gs_ws10
# Out:
# Hourly time
# 2019-03-01 00:00:00.000    1.643117
# 2019-03-01 01:00:00.000    1.617617
# 2019-03-01 01:59:59.990    1.389533
# 2019-03-01 02:59:59.985    1.690217
# 2019-03-01 03:59:59.980    1.622933
#                              ...
# 2019-03-20 19:00:00.000    4.585017
# 2019-03-20 20:00:00.000    3.883667
# 2019-03-20 21:00:00.000    2.242667
# 2019-03-20 22:00:00.000    1.242217
# 2019-03-20 23:00:00.000    1.120217
# Name: gs_ws10, Length: 480, dtype: float64

# %%
df.satellite_ws10
# Out:
# Hourly time
# 2019-03-01 00:00:00.000    1.44
# 2019-03-01 01:00:00.000    1.28
# 2019-03-01 01:59:59.990    1.13
# 2019-03-01 02:59:59.985    1.08
# 2019-03-01 03:59:59.980    1.14
#                            ...
# 2019-03-20 19:00:00.000    1.82
# 2019-03-20 20:00:00.000    1.47
# 2019-03-20 21:00:00.000    1.27
# 2019-03-20 22:00:00.000    1.13
# 2019-03-20 23:00:00.000    1.01
# Name: satellite_ws10, Length: 480, dtype: float64

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(df['satellite_ws10'], label="Satellite")
plt.plot(df['gs_ws10'],label="Ground station")
plt.legend(loc="upper right")
plt.grid()
plt.xlabel('Time(Hourly variation)')
plt.ylabel('Wind Speed (m/sec)')
plt.title('Wind speeds obtained from satellite and ground station')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Wind speeds obtained from satellite and ground station')

# %%
satellite_list=df['satellite_ws10'].tolist()
gs_list=df['gs_ws10'].tolist()
xs=np.array(satellite_list,dtype=np.float64)
ys=np.array(gs_list,dtype=np.float64)
satellite_gs=linear_model.LinearRegression()
satellite_gs.fit(xs.reshape(-1,1),ys)
regression_line=satellite_gs.predict(xs.reshape(-1,1))
style.use('seaborn')
plt.scatter(xs,ys,alpha=0.6,color='green',s=75)
plt.plot(xs,regression_line,label='Best Fit Line',color='orange',linewidth=4)
plt.xlabel('Satellite wind speed (m/sec)')
plt.ylabel('Ground station wind speed (m/sec)')
plt.title('Regression line for the month of March')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['satellite_ws10']],df.gs_ws10)
# Out:
# LinearRegression()

# %%
satellite_gs.coef_
# Out:
# array([0.49882516])

# %%
satellite_gs.intercept_
# Out:
# 1.3109229981891628
